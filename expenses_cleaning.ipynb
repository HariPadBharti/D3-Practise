# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv
df=pd.DataFrame()
df=pd.read_csv('expense.csv')
df.drop('Flag Codes', axis=1, inplace=True)
df.drop('Flags', axis=1, inplace=True)
df.drop('Indicator', axis=1, inplace=True)
df.drop('TIME', axis=1, inplace=True)
df = df[np.isfinite(df['Value'])]

df
# Out:
#        ﻿"EDULIT_IND" LOCATION                Country  Time    Value
# 0       XGDP_1_FSGOV      PER                   Peru  2003  1.05088
# 1       XGDP_1_FSGOV      PER                   Peru  2004  1.10216
# 2       XGDP_1_FSGOV      PER                   Peru  2005  1.02550
# 3       XGDP_1_FSGOV      PER                   Peru  2006  1.08241
# 4       XGDP_1_FSGOV      PER                   Peru  2007  1.07507
# 5       XGDP_1_FSGOV      PER                   Peru  2008  1.15103
# 6       XGDP_1_FSGOV      PER                   Peru  2009  1.26400
# 7       XGDP_1_FSGOV      PER                   Peru  2010  1.13499
# 8       XGDP_1_FSGOV      PER                   Peru  2011  1.04128
# 9       XGDP_1_FSGOV      PER                   Peru  2012  1.06969
# 10      XGDP_1_FSGOV      PER                   Peru  2013  1.30061
# 11      XGDP_1_FSGOV      MNG               Mongolia  2004  1.08437
# 12      XGDP_1_FSGOV      MNG               Mongolia  2007  1.25292
# 13      XGDP_1_FSGOV      MNG               Mongolia  2009  1.40862
# 14      XGDP_1_FSGOV      MNG               Mongolia  2010  1.24935
# 15      XGDP_1_FSGOV      MNG               Mongolia  2011  1.50880
# 17    XGDP_5T8_FSGOV      HUN                Hungary  2003  1.20623
# 18    XGDP_5T8_FSGOV      HUN                Hungary  2004  1.00585
# 19    XGDP_5T8_FSGOV      HUN                Hungary  2005  1.01688
# 20    XGDP_5T8_FSGOV      HUN                Hungary  2006  1.02563
# 21    XGDP_5T8_FSGOV      HUN                Hungary  2007  1.02398
# 22    XGDP_5T8_FSGOV      HUN                Hungary  2008  1.00521
# 23    XGDP_5T8_FSGOV      HUN                Hungary  2009  1.10546
# 24    XGDP_5T8_FSGOV      HUN                Hungary  2010  0.96900
# 25    XGDP_5T8_FSGOV      HUN                Hungary  2011  1.08660
# 26    XGDP_5T8_FSGOV      HUN                Hungary  2012  0.80313
# 27     XGDP_02_FSGOV      NAM                Namibia  2003  0.03000
# 28     XGDP_02_FSGOV      NAM                Namibia  2005  0.03171
# 29     XGDP_02_FSGOV      NAM                Namibia  2006  0.03238
# 30     XGDP_02_FSGOV      NAM                Namibia  2008  0.02590
# ...              ...      ...                    ...   ...      ...
# 5957    XGDP_1_FSGOV      GNB          Guinea-Bissau  2010  0.87097
# 5958    XGDP_1_FSGOV      GNB          Guinea-Bissau  2011  0.93643
# 5959    XGDP_1_FSGOV      GNB          Guinea-Bissau  2012  1.16128
# 5960    XGDP_1_FSGOV      GNB          Guinea-Bissau  2013  1.51760
# 5963  XGDP_2T3_FSGOV      STP  Sao Tome and Principe  2012  1.29236
# 5964  XGDP_2T3_FSGOV      STP  Sao Tome and Principe  2013  1.56174
# 5965    XGDP_1_FSGOV      KAZ             Kazakhstan  2013  0.01942
# 5966    XGDP_4_FSGOV      PRI            Puerto Rico  2013  0.15261
# 5967  XGDP_5T8_FSGOV      STP  Sao Tome and Principe  2012  0.98048
# 5968  XGDP_5T8_FSGOV      STP  Sao Tome and Principe  2013  0.47809
# 5969   XGDP_02_FSGOV      GNB          Guinea-Bissau  2010  0.01249
# 5970   XGDP_02_FSGOV      GNB          Guinea-Bissau  2011  0.01397
# 5971   XGDP_02_FSGOV      GNB          Guinea-Bissau  2012  0.01748
# 5972   XGDP_02_FSGOV      GNB          Guinea-Bissau  2013  0.01769
# 5973    XGDP_1_FSGOV      STP  Sao Tome and Principe  2012  3.13280
# 5974    XGDP_1_FSGOV      STP  Sao Tome and Principe  2013  3.08657
# 5975    XGDP_1_FSGOV      PRI            Puerto Rico  2013  1.38118
# 5976  XGDP_2T3_FSGOV      KGZ             Kyrgyzstan  2013  3.68646
# 5978    XGDP_4_FSGOV      GNB          Guinea-Bissau  2010  0.01735
# 5979    XGDP_4_FSGOV      GNB          Guinea-Bissau  2011  0.01507
# 5980    XGDP_4_FSGOV      GNB          Guinea-Bissau  2012  0.01465
# 5981    XGDP_4_FSGOV      GNB          Guinea-Bissau  2013  0.01152
# 5982  XGDP_2T3_FSGOV      PRI            Puerto Rico  2013  1.50395
# 5983   XGDP_02_FSGOV      PRI            Puerto Rico  2013  0.45966
# 5984  XGDP_2T3_FSGOV      KAZ             Kazakhstan  2013  1.85453
# 5985    XGDP_1_FSGOV      ALB                Albania  2013  1.99323
# 5986  XGDP_5T8_FSGOV      PRI            Puerto Rico  2013  2.46251
# 5987  XGDP_5T8_FSGOV      ALB                Albania  2013  0.76770
# 5989    XGDP_1_FSGOV      TLS            Timor-Leste  2011  6.88522
# 5990  XGDP_2T3_FSGOV      TLS            Timor-Leste  2011  0.70508
#
# [5298 rows x 5 columns]
